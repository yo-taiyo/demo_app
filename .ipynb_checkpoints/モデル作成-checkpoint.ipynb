# %% [markdown]
# ## モデル作成
# - データの読み込み
#     - 欠損値があるか
#     - 文字列データの有無の確認
# - 特定の列の削除
#     - BILL_AMT2~6
# - データを検証データと訓練データへ切り分け:(テストデータ30%)
# - 学習：決定木(分類)
# - モデルの保存 → demo_model.pkl
# - モデルの読み込み-
# -  推論
#
# 'default payment next month'が教師データ t

# %%
import pandas as pd
import numpy as np
# %matplotlib
# Out:
# Using matplotlib backend: MacOSX

# %%
df = pd.read_csv('default.csv')

# %%
df.head(2)
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
#
#    PAY_5             ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  \
# 0     -2             ...                      0          0          0
# 1      0             ...                   3272       3455       3261
#
#    PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0         0       689         0         0         0         0
# 1         0      1000      1000      1000         0      2000
#
#    default payment next month
# 0                           1
# 1                           1
#
# [2 rows x 24 columns]

# %%
df.isnull().sum
# Out:
# <bound method DataFrame.sum of        LIMIT_BAL    SEX  EDUCATION  MARRIAGE    AGE  PAY_0  PAY_2  PAY_3  \
# 0          False  False      False     False  False  False  False  False
# 1          False  False      False     False  False  False  False  False
# 2          False  False      False     False  False  False  False  False
# 3          False  False      False     False  False  False  False  False
# 4          False  False      False     False  False  False  False  False
# 5          False  False      False     False  False  False  False  False
# 6          False  False      False     False  False  False  False  False
# 7          False  False      False     False  False  False  False  False
# 8          False  False      False     False  False  False  False  False
# 9          False  False      False     False  False  False  False  False
# 10         False  False      False     False  False  False  False  False
# ...

# %%
df.select_dtypes(include='int')
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0          20000    2          2         1   24      2      2     -1     -1
# 1         120000    2          2         2   26     -1      2      0      0
# 2          90000    2          2         2   34      0      0      0      0
# 3          50000    2          2         1   37      0      0      0      0
# 4          50000    1          2         1   57     -1      0     -1      0
# 5          50000    1          1         2   37      0      0      0      0
# 6         500000    1          1         2   29      0      0      0      0
# 7         100000    2          2         2   23      0     -1     -1      0
# 8         140000    2          3         1   28      0      0      2      0
# 9          20000    1          3         2   35     -2     -2     -2     -2
# 10        200000    2          3         2   34      0      0      2      0
# ...

# %%
df.drop(labels=['BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6',])

# %%
for i in range(2,7):
    df.drop(lables=['BILL_AMT{}'.format(i)], inplace=True, axies=1) #axis=1　列、0行
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-fa86c169cfa9> in <module>()
#       1 for i in range(2,7):
# ----> 2     df.drop(lables=['BILL_AMT{}'.format(i)], inplace=True, axies=1) #axis=1　列、0行
#
# TypeError: drop() got an unexpected keyword argument 'lables'

# %% [markdown]
# ## result.htmlを表示してください
#
# - URL名は result
# - view関数名も result
# - html名も result.html
#     - 審査結果
# - input_formで入力完了した時、result のページにリダイレクトするように設定

# %% [markdown]
# ## 入力変数xを使用して推論を行ってください。
# - y ← 推論結果
# - y_proba ← 自信度（確率）

# %% [markdown]
# ## 自信度によって表示する文言を条件分岐させてください。
#
# - 分類結果によって分岐
#   - 自信度によって分岐
#
# - 分類結果が0の場合(審査に落ちている)
#   - 自信度が0.75以上→コメント1
#   - 自信度が0.75未満→コメント2
# - 分類結果が1の場合(審査自体は合格)
#   - 自信度が0.75以上→コメント3
#   - 自信度が0.75未満→コメント4
#
# コメントは自由に作成してください。
# comment という変数名でHTMLファイルにわたし、表示してください。

# %% [markdown]
# ## /historyのページの作成
#
# 「顧客一覧」という文字が表示されるページを作成
#
# - urlは ' /history'
# - HTMLファイル名は history.html
#
# ヒント
# - urls.pyの編集
# - view.pyの編集
# - Templatesの作成

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('sample_demographic.csv')

# %%
df.head(2)
# Out:
#    sex  education  marriage  age  result     proba  edu
# 0    2          4         1   86       0  0.198154    3
# 1    1          3         1   21       0  0.599666    4

# %%
'Customer.object.values_list('sex', 'education')'
# Out:
#   File "<ipython-input-4-d7952e10a07f>", line 1
#     'Customer.object.values_list('sex', 'education')'
#                                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### データの置換

# %%
df['sex'].replace()
# Out:
# 0     2
# 1     1
# 2     2
# 3     2
# 4     2
# 5     1
# 6     1
# 7     2
# 8     2
# 9     1
# 10    1
# 11    2
# 12    2
# 13    2
# 14    1
# 15    2
# 16    1
# 17    1
# 18    1
# 19    2
# 20    2
# 21    1
# 22    2
# 23    1
# 24    1
# 25    1
# 26    1
# 27    1
# 28    1
# 29    2
# Name: sex, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# 1    16
# 2    14
# Name: sex, dtype: int64

# %%
df['sex'].value_counts().index
# Out:
# Int64Index([1, 2], dtype='int64')

# %%
df['sex'].replace({1:'男性', 2:'女性'}, inplace=True)
# Out:
# 0     女性
# 1     男性
# 2     女性
# 3     女性
# 4     女性
# 5     男性
# 6     男性
# 7     女性
# 8     女性
# 9     男性
# 10    男性
# 11    女性
# 12    女性
# 13    女性
# 14    男性
# 15    女性
# 16    男性
# 17    男性
# 18    男性
# 19    女性
# 20    女性
# 21    男性
# 22    女性
# 23    男性
# 24    男性
# 25    男性
# 26    男性
# 27    男性
# 28    男性
# 29    女性
# Name: sex, dtype: object
